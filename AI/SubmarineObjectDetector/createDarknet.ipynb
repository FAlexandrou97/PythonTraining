# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Install cudnn from google drive

# We're unzipping the cuDNN files from your Drive folder directly to the VM CUDA folders
# !tar -xzvf /content/gdrive/My\ Drive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz -C /usr/local/
# !chmod a+r /usr/local/cuda/include/cudnn.h

# Now we check the version we already installed. Can comment this line on future runs
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
# Leave this code uncommented on the very first run of your notebook or if you ever need to recompile darknet again.
# Comment this code on the future runs.
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet

# Check the folder
# !ls

# I have a branch where I have done the changes commented above
# !git checkout feature/google-colab

#Compile Darknet
# !make
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 9.97 MiB | 5.68 MiB/s, done.
# Resolving deltas: 100% (6769/6769), done.
# /content/darknet
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     scripts
# appveyor.yml  CMakeSettings.json      include		     src
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  video_v2.sh
# build.ps1     darknet.py	      LICENSE		     video_yolov3.sh
# build.sh      darknet_video.py	      Makefile
# cfg	      data		      net_cam_v3.sh
# cmake	      image_yolov2.sh	      README.md
# Branch 'feature/google-colab' set up to track remote branch 'feature/google-colab' from 'origin'.
# Switched to a new branch 'feature/google-colab'
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(mat_cv*, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:896:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:228:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:475:23: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (n < outlen)
#                      ~~^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2016:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2015:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘get_cuda_stream’:
# ./src/dark_cuda.c:120:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^~~~~~
# ./src/dark_cuda.c: In function ‘get_cuda_memcpy_stream’:
# ./src/dark_cuda.c:141:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^~~~~~
# ./src/dark_cuda.c: In function ‘cudnn_handle’:
# ./src/dark_cuda.c:161:23: warning: unused variable ‘status’ [-Wunused-variable]
#          cudnnStatus_t status = cudnnSetStream(handle[i], get_cuda_stream());
#                        ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:951:28: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                      size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                             ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# ./src/maxpool_layer.c: In function ‘cudnn_maxpool_setup’:
# ./src/maxpool_layer.c:26:19: warning: variable ‘maxpool_status’ set but not used [-Wunused-but-set-variable]
#      cudnnStatus_t maxpool_status;
#                    ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:511:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:335:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:333:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:332:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:331:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:330:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:329:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:328:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:874:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1008:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1007:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:58:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:65:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:92:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:101:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %%
# don't go beyond here with Run All
# assert False

# %%
# Copy training data to VM local system to increase training speed.

# Copy files from Google Drive to the VM local filesystem
# !git clone https://github.com/FAlexandrou97/sodTrainingData.git ./img
# !ls
# Out:
# Cloning into './img'...
# remote: Enumerating objects: 2, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6708 (delta 0), reused 1 (delta 0), pack-reused 6706
# Receiving objects: 100% (6708/6708), 585.47 MiB | 14.64 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# Checking out files: 100% (6322/6322), done.
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     README.md
# appveyor.yml  CMakeSettings.json      img		     results
# backup	      darknet		      include		     scripts
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  src
# build.ps1     darknet.py	      LICENSE		     video_v2.sh
# build.sh      darknet_video.py	      Makefile		     video_yolov3.sh
# cfg	      data		      net_cam_v3.sh
# cmake	      image_yolov2.sh	      obj

# %%
# !./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/cfg/sub-yolov3_16div.cfg" "/content/gdrive/My Drive/darknet/backup/sub-yolov3_16div_10000_V1.weights" -dont_show
# Out:
# sub-yolov3_16div
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
#   13 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   14 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   17 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   20 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   23 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   26 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   29 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   32 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   35 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    52 x  52 x 256   ->    26 x  26 x 512 1.595 BF
#   38 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   39 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   42 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   45 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   48 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   51 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   54 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   57 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   60 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    26 x  26 x 512   ->    13 x  13 x1024 1.595 BF
#   63 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   64 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   67 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   70 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   73 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   76 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   77 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   78 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   79 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   80 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   81 conv     30  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x  30 0.010 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x 256 0.044 BF
#   85 upsample            2x    13 x  13 x 256   ->    26 x  26 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    26 x  26 x 768   ->    26 x  26 x 256 0.266 BF
#   88 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   89 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   90 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   91 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   92 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   93 conv     30  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x  30 0.021 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x 128 0.044 BF
#   97 upsample            2x    26 x  26 x 128   ->    52 x  52 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    52 x  52 x 384   ->    52 x  52 x 128 0.266 BF
#  100 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  101 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  102 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  103 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  104 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  105 conv     30  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x  30 0.042 BF
#  106 yolo
# Total BFLOPS 65.319
#  Allocate additional workspace_size = 12.46 MB
# Loading weights from /content/gdrive/My Drive/darknet/backup/sub-yolov3_16div_10000_V1.weights...
#  seen 64
# Done!
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000054 seconds
#
#  10001: 0.477837, 0.477837 avg loss, 0.001000 rate, 22.245496 seconds, 640064 images
# Loaded: 0.000073 seconds
#
#  10002: 0.556121, 0.485665 avg loss, 0.001000 rate, 22.825253 seconds, 640128 images
# Loaded: 0.000056 seconds
#
#  10003: 0.454295, 0.482528 avg loss, 0.001000 rate, 22.815766 seconds, 640192 images
# Loaded: 0.000049 seconds
#
#  10004: 0.511107, 0.485386 avg loss, 0.001000 rate, 22.773038 seconds, 640256 images
# Loaded: 0.000053 seconds
#
#  10005: 0.368936, 0.473741 avg loss, 0.001000 rate, 22.755215 seconds, 640320 images
# Loaded: 0.000056 seconds
#
#  10006: 0.415436, 0.467910 avg loss, 0.001000 rate, 22.739635 seconds, 640384 images
# Loaded: 0.000050 seconds
#
#  10007: 0.729925, 0.494112 avg loss, 0.001000 rate, 22.725091 seconds, 640448 images
# Loaded: 0.000053 seconds
#
#  10008: 0.992779, 0.543979 avg loss, 0.001000 rate, 22.763249 seconds, 640512 images
# Loaded: 0.000065 seconds
#
#  10009: 0.360294, 0.525610 avg loss, 0.001000 rate, 22.747698 seconds, 640576 images
# Loaded: 0.000048 seconds
#
#  10010: 0.275352, 0.500584 avg loss, 0.001000 rate, 22.713371 seconds, 640640 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.217765 seconds
#
#  10011: 0.782301, 0.528756 avg loss, 0.001000 rate, 21.878395 seconds, 640704 images
# Loaded: 0.000054 seconds
#
#  10012: 0.445522, 0.520433 avg loss, 0.001000 rate, 22.725474 seconds, 640768 images
# Loaded: 0.000076 seconds
#
#  10013: 0.217613, 0.490151 avg loss, 0.001000 rate, 22.760401 seconds, 640832 images
# Loaded: 0.000066 seconds
#
#  10014: 0.886833, 0.529819 avg loss, 0.001000 rate, 22.770247 seconds, 640896 images
# Loaded: 0.000054 seconds
#
#  10015: 0.425637, 0.519401 avg loss, 0.001000 rate, 22.729849 seconds, 640960 images
# Loaded: 0.000053 seconds
#
#  10016: 1.146458, 0.582106 avg loss, 0.001000 rate, 22.828985 seconds, 641024 images
# Loaded: 0.000058 seconds
#
#  10017: 0.531095, 0.577005 avg loss, 0.001000 rate, 22.750905 seconds, 641088 images
# Loaded: 0.000051 seconds
#
#  10018: 0.337907, 0.553096 avg loss, 0.001000 rate, 22.732066 seconds, 641152 images
# Loaded: 0.000062 seconds
#
#  10019: 0.237147, 0.521501 avg loss, 0.001000 rate, 22.721367 seconds, 641216 images
# Loaded: 0.000066 seconds
#
#  10020: 0.425137, 0.511864 avg loss, 0.001000 rate, 22.740280 seconds, 641280 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000054 seconds
#
#  10021: 0.390907, 0.499769 avg loss, 0.001000 rate, 8.065528 seconds, 641344 images
# Loaded: 0.000055 seconds
#
#  10022: 0.616526, 0.511444 avg loss, 0.001000 rate, 8.378015 seconds, 641408 images
# Loaded: 0.000035 seconds
#
#  10023: 0.193793, 0.479679 avg loss, 0.001000 rate, 8.371848 seconds, 641472 images
# Loaded: 0.000081 seconds
#
#  10024: 0.796658, 0.511377 avg loss, 0.001000 rate, 8.378216 seconds, 641536 images
# Loaded: 0.000051 seconds
#
#  10025: 0.122379, 0.472477 avg loss, 0.001000 rate, 8.382010 seconds, 641600 images
# Loaded: 0.000055 seconds
#
#  10026: 0.435450, 0.468774 avg loss, 0.001000 rate, 8.371272 seconds, 641664 images
# Loaded: 0.000074 seconds
#
#  10027: 0.270667, 0.448964 avg loss, 0.001000 rate, 8.384144 seconds, 641728 images
# Loaded: 0.000044 seconds
#
#  10028: 0.824449, 0.486512 avg loss, 0.001000 rate, 8.376588 seconds, 641792 images
# Loaded: 0.000050 seconds
#
#  10029: 0.810461, 0.518907 avg loss, 0.001000 rate, 8.381667 seconds, 641856 images
# Loaded: 0.000053 seconds
#
#  10030: 0.150584, 0.482075 avg loss, 0.001000 rate, 8.367099 seconds, 641920 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.276676 seconds
#
#  10031: 0.263622, 0.460230 avg loss, 0.001000 rate, 8.066005 seconds, 641984 images
# Loaded: 0.000059 seconds
#
#  10032: 0.132534, 0.427460 avg loss, 0.001000 rate, 8.401503 seconds, 642048 images
# Loaded: 0.000057 seconds
#
#  10033: 0.463602, 0.431074 avg loss, 0.001000 rate, 8.405551 seconds, 642112 images
# Loaded: 0.000064 seconds
#
#  10034: 0.400055, 0.427972 avg loss, 0.001000 rate, 8.421097 seconds, 642176 images
# Loaded: 0.000064 seconds
#
#  10035: 0.271763, 0.412351 avg loss, 0.001000 rate, 8.406433 seconds, 642240 images
# Loaded: 0.000049 seconds
#
#  10036: 0.431872, 0.414303 avg loss, 0.001000 rate, 8.404730 seconds, 642304 images
# Loaded: 0.000069 seconds
#
#  10037: 0.407509, 0.413624 avg loss, 0.001000 rate, 8.421093 seconds, 642368 images
# Loaded: 0.000059 seconds
#
#  10038: 0.086869, 0.380948 avg loss, 0.001000 rate, 8.388371 seconds, 642432 images
# Loaded: 0.000066 seconds
#
#  10039: 0.593241, 0.402178 avg loss, 0.001000 rate, 8.403911 seconds, 642496 images
# Loaded: 0.000070 seconds
#
#  10040: 0.305460, 0.392506 avg loss, 0.001000 rate, 8.412158 seconds, 642560 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.445599 seconds
#
#  10041: 0.371031, 0.390358 avg loss, 0.001000 rate, 8.076525 seconds, 642624 images
# Loaded: 0.000062 seconds
#
#  10042: 0.498145, 0.401137 avg loss, 0.001000 rate, 8.420178 seconds, 642688 images
# Loaded: 0.000088 seconds
#
#  10043: 0.204735, 0.381497 avg loss, 0.001000 rate, 8.400673 seconds, 642752 images
# Loaded: 0.000064 seconds
#
#  10044: 0.595142, 0.402861 avg loss, 0.001000 rate, 8.398139 seconds, 642816 images
# Loaded: 0.000061 seconds
#
#  10045: 0.267547, 0.389330 avg loss, 0.001000 rate, 8.416384 seconds, 642880 images
# Loaded: 0.000062 seconds
#
#  10046: 0.620761, 0.412473 avg loss, 0.001000 rate, 8.414516 seconds, 642944 images
# Loaded: 0.000065 seconds
#
#  10047: 0.139014, 0.385127 avg loss, 0.001000 rate, 8.419042 seconds, 643008 images
# Loaded: 0.000052 seconds
#
#  10048: 0.468547, 0.393469 avg loss, 0.001000 rate, 8.405835 seconds, 643072 images
# Loaded: 0.000063 seconds
#
#  10049: 0.326077, 0.386730 avg loss, 0.001000 rate, 8.409890 seconds, 643136 images
# Loaded: 0.000066 seconds
#
#  10050: 0.394703, 0.387527 avg loss, 0.001000 rate, 8.383977 seconds, 643200 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000055 seconds
#
#  10051: 0.474772, 0.396252 avg loss, 0.001000 rate, 14.311686 seconds, 643264 images
# Loaded: 0.000066 seconds
#
#  10052: 0.339427, 0.390569 avg loss, 0.001000 rate, 14.856243 seconds, 643328 images
# Loaded: 0.000058 seconds
#
#  10053: 0.214532, 0.372965 avg loss, 0.001000 rate, 14.854287 seconds, 643392 images
# Loaded: 0.000062 seconds
#
#  10054: 0.315271, 0.367196 avg loss, 0.001000 rate, 14.851144 seconds, 643456 images
# Loaded: 0.000052 seconds
#
#  10055: 0.309048, 0.361381 avg loss, 0.001000 rate, 14.850898 seconds, 643520 images
# Loaded: 0.000053 seconds
#
#  10056: 0.364927, 0.361736 avg loss, 0.001000 rate, 14.861340 seconds, 643584 images
# Loaded: 0.000070 seconds
#
#  10057: 0.429823, 0.368545 avg loss, 0.001000 rate, 14.828643 seconds, 643648 images
# Loaded: 0.000054 seconds
#
#  10058: 0.123596, 0.344050 avg loss, 0.001000 rate, 14.854937 seconds, 643712 images
# Loaded: 0.000051 seconds
#
#  10059: 1.156513, 0.425296 avg loss, 0.001000 rate, 14.869306 seconds, 643776 images
# Loaded: 0.000050 seconds
#
#  10060: 0.463758, 0.429142 avg loss, 0.001000 rate, 14.858144 seconds, 643840 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 12.46 MB
#  CUDA allocate done!
# Loaded: 0.339889 seconds
#
#  10061: 0.163901, 0.402618 avg loss, 0.001000 rate, 10.856847 seconds, 643904 images
# Loaded: 0.000054 seconds
#
#  10062: 0.479788, 0.410335 avg loss, 0.001000 rate, 11.300510 seconds, 643968 images
# Loaded: 0.000049 seconds
#
#  10063: 0.078640, 0.377166 avg loss, 0.001000 rate, 11.285312 seconds, 644032 images
# Loaded: 0.000046 seconds
#
#  10064: 0.485866, 0.388036 avg loss, 0.001000 rate, 11.307802 seconds, 644096 images
# Loaded: 0.000057 seconds
#
#  10065: 0.211664, 0.370399 avg loss, 0.001000 rate, 11.304574 seconds, 644160 images
# Loaded: 0.000058 seconds
#
#  10066: 0.273290, 0.360688 avg loss, 0.001000 rate, 11.279257 seconds, 644224 images
# Loaded: 0.000052 seconds
#
#  10067: 0.727216, 0.397341 avg loss, 0.001000 rate, 11.345428 seconds, 644288 images
# Loaded: 0.000056 seconds
#
#  10068: 0.503212, 0.407928 avg loss, 0.001000 rate, 11.293337 seconds, 644352 images
# Loaded: 0.000050 seconds
#
#  10069: 0.165618, 0.383697 avg loss, 0.001000 rate, 11.274640 seconds, 644416 images
# Loaded: 0.000051 seconds
#
#  10070: 0.175945, 0.362922 avg loss, 0.001000 rate, 11.294192 seconds, 644480 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000069 seconds
#
#  10071: 0.448380, 0.371467 avg loss, 0.001000 rate, 12.027026 seconds, 644544 images
# Loaded: 0.000067 seconds
#
#  10072: 0.569248, 0.391246 avg loss, 0.001000 rate, 12.569282 seconds, 644608 images
# Loaded: 0.000082 seconds
#
#  10073: 0.819995, 0.434120 avg loss, 0.001000 rate, 12.555055 seconds, 644672 images
# Loaded: 0.000081 seconds
#
#  10074: 0.234770, 0.414185 avg loss, 0.001000 rate, 12.530465 seconds, 644736 images
# Loaded: 0.000041 seconds
#
#  10075: 0.846033, 0.457370 avg loss, 0.001000 rate, 12.500855 seconds, 644800 images
# Loaded: 0.000052 seconds
#
#  10076: 0.479625, 0.459596 avg loss, 0.001000 rate, 12.537947 seconds, 644864 images
# Loaded: 0.000059 seconds
#
#  10077: 0.399767, 0.453613 avg loss, 0.001000 rate, 12.534003 seconds, 644928 images
# Loaded: 0.000059 seconds
#
#  10078: 0.670181, 0.475270 avg loss, 0.001000 rate, 12.564934 seconds, 644992 images
# Loaded: 0.000050 seconds
#
#  10079: 0.854076, 0.513150 avg loss, 0.001000 rate, 12.509790 seconds, 645056 images
# Loaded: 0.000064 seconds
#
#  10080: 0.372005, 0.499036 avg loss, 0.001000 rate, 12.516997 seconds, 645120 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000122 seconds
#
#  10081: 0.307009, 0.479833 avg loss, 0.001000 rate, 21.950341 seconds, 645184 images
# Loaded: 0.000078 seconds
#
#  10082: 0.665757, 0.498425 avg loss, 0.001000 rate, 22.807336 seconds, 645248 images
# Loaded: 0.000062 seconds
#
#  10083: 0.289227, 0.477506 avg loss, 0.001000 rate, 22.771079 seconds, 645312 images
# Loaded: 0.000053 seconds
#
#  10084: 0.553316, 0.485087 avg loss, 0.001000 rate, 22.767767 seconds, 645376 images
# Loaded: 0.000056 seconds
#
#  10085: 0.755397, 0.512118 avg loss, 0.001000 rate, 22.795939 seconds, 645440 images
# Loaded: 0.000056 seconds
#
#  10086: 0.805606, 0.541466 avg loss, 0.001000 rate, 22.784206 seconds, 645504 images
# Loaded: 0.000065 seconds
#
#  10087: 0.402640, 0.527584 avg loss, 0.001000 rate, 22.740209 seconds, 645568 images
# Loaded: 0.000087 seconds
#
#  10088: 0.337335, 0.508559 avg loss, 0.001000 rate, 22.759377 seconds, 645632 images
# Loaded: 0.000057 seconds
#
#  10089: 0.295212, 0.487224 avg loss, 0.001000 rate, 22.774811 seconds, 645696 images
# Loaded: 0.000058 seconds
#
#  10090: 0.510357, 0.489538 avg loss, 0.001000 rate, 22.765992 seconds, 645760 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000047 seconds
#
#  10091: 0.550579, 0.495642 avg loss, 0.001000 rate, 14.273735 seconds, 645824 images
# Loaded: 0.000049 seconds
#
#  10092: 0.097604, 0.455838 avg loss, 0.001000 rate, 14.832835 seconds, 645888 images
# Loaded: 0.000080 seconds
#
#  10093: 0.216605, 0.431915 avg loss, 0.001000 rate, 14.829508 seconds, 645952 images
# Loaded: 0.000059 seconds
#
#  10094: 0.407305, 0.429454 avg loss, 0.001000 rate, 14.861834 seconds, 646016 images
# Loaded: 0.000068 seconds
#
#  10095: 0.374153, 0.423924 avg loss, 0.001000 rate, 14.847275 seconds, 646080 images
# Loaded: 0.000066 seconds
#
#  10096: 0.310934, 0.412625 avg loss, 0.001000 rate, 14.846440 seconds, 646144 images
# Loaded: 0.000057 seconds
#
#  10097: 0.389605, 0.410323 avg loss, 0.001000 rate, 14.860589 seconds, 646208 images
# Loaded: 0.000074 seconds
#
#  10098: 0.130848, 0.382375 avg loss, 0.001000 rate, 14.854980 seconds, 646272 images
# Loaded: 0.000058 seconds
#
#  10099: 0.110469, 0.355185 avg loss, 0.001000 rate, 14.842717 seconds, 646336 images
# Loaded: 0.000049 seconds
#
#  10100: 0.196398, 0.339306 avg loss, 0.001000 rate, 14.835361 seconds, 646400 images
# Saving weights to /content/gdrive/My Drive/darknet/backup//sub-yolov3_16div_last.weights
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000094 seconds
#
#  10101: 0.649411, 0.370316 avg loss, 0.001000 rate, 19.772112 seconds, 646464 images
# Loaded: 0.000056 seconds
#
#  10102: 0.373596, 0.370644 avg loss, 0.001000 rate, 20.558199 seconds, 646528 images
# Loaded: 0.000058 seconds
#
#  10103: 0.254462, 0.359026 avg loss, 0.001000 rate, 20.534065 seconds, 646592 images
# Loaded: 0.000049 seconds
#
#  10104: 0.370308, 0.360154 avg loss, 0.001000 rate, 20.542988 seconds, 646656 images
# Loaded: 0.000058 seconds
#
#  10105: 0.183637, 0.342503 avg loss, 0.001000 rate, 20.512707 seconds, 646720 images
# Loaded: 0.000095 seconds
#
#  10106: 0.272621, 0.335515 avg loss, 0.001000 rate, 20.528334 seconds, 646784 images
# Loaded: 0.000052 seconds
#
#  10107: 0.193052, 0.321268 avg loss, 0.001000 rate, 20.520848 seconds, 646848 images
# Loaded: 0.000060 seconds
#
#  10108: 0.123488, 0.301490 avg loss, 0.001000 rate, 20.525543 seconds, 646912 images
# Loaded: 0.000051 seconds
#
#  10109: 0.224049, 0.293746 avg loss, 0.001000 rate, 20.509188 seconds, 646976 images
# Loaded: 0.000063 seconds
#
#  10110: 0.473819, 0.311753 avg loss, 0.001000 rate, 20.525720 seconds, 647040 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000068 seconds
#
#  10111: 0.669739, 0.347552 avg loss, 0.001000 rate, 15.575474 seconds, 647104 images
# Loaded: 0.000086 seconds
#
#  10112: 0.320603, 0.344857 avg loss, 0.001000 rate, 16.159006 seconds, 647168 images
# Loaded: 0.000078 seconds
#
#  10113: 0.187773, 0.329149 avg loss, 0.001000 rate, 16.103723 seconds, 647232 images
# Loaded: 0.000057 seconds
#
#  10114: 0.438505, 0.340084 avg loss, 0.001000 rate, 16.087934 seconds, 647296 images
# Loaded: 0.000058 seconds
#
#  10115: 0.101766, 0.316252 avg loss, 0.001000 rate, 16.137099 seconds, 647360 images
# Loaded: 0.000043 seconds
#
#  10116: 0.526932, 0.337320 avg loss, 0.001000 rate, 16.165939 seconds, 647424 images
# Loaded: 0.000066 seconds
#
#  10117: 0.266350, 0.330223 avg loss, 0.001000 rate, 16.165518 seconds, 647488 images
# Loaded: 0.000063 seconds
#
#  10118: 0.301108, 0.327312 avg loss, 0.001000 rate, 16.103645 seconds, 647552 images
# Loaded: 0.000054 seconds
#
#  10119: 0.227981, 0.317379 avg loss, 0.001000 rate, 16.180691 seconds, 647616 images
# Loaded: 0.000055 seconds
#
#  10120: 0.151465, 0.300787 avg loss, 0.001000 rate, 16.136595 seconds, 647680 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000088 seconds
#
#  10121: 0.322360, 0.302945 avg loss, 0.001000 rate, 19.727322 seconds, 647744 images
# Loaded: 0.000067 seconds
#
#  10122: 0.155202, 0.288170 avg loss, 0.001000 rate, 20.513869 seconds, 647808 images
# Loaded: 0.000066 seconds
#
#  10123: 0.242730, 0.283626 avg loss, 0.001000 rate, 20.517741 seconds, 647872 images
# Loaded: 0.000060 seconds
#
#  10124: 0.149813, 0.270245 avg loss, 0.001000 rate, 20.558871 seconds, 647936 images
# Loaded: 0.000051 seconds
#
#  10125: 0.403288, 0.283549 avg loss, 0.001000 rate, 20.560226 seconds, 648000 images
# Loaded: 0.000038 seconds
#
#  10126: 0.494585, 0.304653 avg loss, 0.001000 rate, 20.566847 seconds, 648064 images
# Loaded: 0.000073 seconds
#
#  10127: 0.446784, 0.318866 avg loss, 0.001000 rate, 20.557382 seconds, 648128 images
# Loaded: 0.000049 seconds
#
#  10128: 0.429632, 0.329943 avg loss, 0.001000 rate, 20.541577 seconds, 648192 images
# Loaded: 0.000051 seconds
#
#  10129: 0.533538, 0.350302 avg loss, 0.001000 rate, 20.564080 seconds, 648256 images
# Loaded: 0.000059 seconds
#
#  10130: 0.167768, 0.332049 avg loss, 0.001000 rate, 20.516099 seconds, 648320 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000047 seconds
#
#  10131: 0.473866, 0.346231 avg loss, 0.001000 rate, 8.046430 seconds, 648384 images
# Loaded: 0.000061 seconds
#
#  10132: 0.446340, 0.356241 avg loss, 0.001000 rate, 8.391671 seconds, 648448 images
# Loaded: 0.000093 seconds
#
#  10133: 0.429757, 0.363593 avg loss, 0.001000 rate, 8.360594 seconds, 648512 images
# Loaded: 0.000077 seconds
#
#  10134: 0.635639, 0.390798 avg loss, 0.001000 rate, 8.380515 seconds, 648576 images
# Loaded: 0.000062 seconds
#
#  10135: 0.340207, 0.385738 avg loss, 0.001000 rate, 8.378185 seconds, 648640 images
# Loaded: 0.000092 seconds
#
#  10136: 0.248092, 0.371974 avg loss, 0.001000 rate, 8.375338 seconds, 648704 images
# Loaded: 0.000049 seconds
#
#  10137: 0.173017, 0.352078 avg loss, 0.001000 rate, 8.372309 seconds, 648768 images
# Loaded: 0.000056 seconds
#
#  10138: 0.292569, 0.346127 avg loss, 0.001000 rate, 8.380275 seconds, 648832 images
# Loaded: 0.000048 seconds
#
#  10139: 0.544390, 0.365954 avg loss, 0.001000 rate, 8.369752 seconds, 648896 images
# Loaded: 0.000051 seconds
#
#  10140: 0.256329, 0.354991 avg loss, 0.001000 rate, 8.396906 seconds, 648960 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000060 seconds
#
#  10141: 0.094633, 0.328955 avg loss, 0.001000 rate, 17.979297 seconds, 649024 images
# Loaded: 0.000062 seconds
#
#  10142: 0.188542, 0.314914 avg loss, 0.001000 rate, 18.646009 seconds, 649088 images
# Loaded: 0.000052 seconds
#
#  10143: 0.323686, 0.315791 avg loss, 0.001000 rate, 18.681362 seconds, 649152 images
# Loaded: 0.000064 seconds
#
#  10144: 0.486491, 0.332861 avg loss, 0.001000 rate, 18.670507 seconds, 649216 images
# Loaded: 0.000087 seconds
#
#  10145: 0.244686, 0.324044 avg loss, 0.001000 rate, 18.687315 seconds, 649280 images
# Loaded: 0.000094 seconds
#
#  10146: 0.228819, 0.314521 avg loss, 0.001000 rate, 18.674628 seconds, 649344 images
# Loaded: 0.000058 seconds
#
#  10147: 0.358102, 0.318879 avg loss, 0.001000 rate, 18.680062 seconds, 649408 images
# Loaded: 0.000082 seconds
#
#  10148: 0.191690, 0.306160 avg loss, 0.001000 rate, 18.664768 seconds, 649472 images
# Loaded: 0.000053 seconds
#
#  10149: 0.254832, 0.301027 avg loss, 0.001000 rate, 18.667113 seconds, 649536 images
# Loaded: 0.000051 seconds
#
#  10150: 0.137586, 0.284683 avg loss, 0.001000 rate, 18.681953 seconds, 649600 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000054 seconds
#
#  10151: 0.289166, 0.285132 avg loss, 0.001000 rate, 12.010394 seconds, 649664 images
# Loaded: 0.000061 seconds
#
#  10152: 0.082062, 0.264825 avg loss, 0.001000 rate, 12.528157 seconds, 649728 images
# Loaded: 0.000049 seconds
#
#  10153: 0.745977, 0.312940 avg loss, 0.001000 rate, 12.517363 seconds, 649792 images
# Loaded: 0.000048 seconds
#
#  10154: 0.932328, 0.374879 avg loss, 0.001000 rate, 12.543551 seconds, 649856 images
# Loaded: 0.000066 seconds
#
#  10155: 0.209122, 0.358303 avg loss, 0.001000 rate, 12.549686 seconds, 649920 images
# Loaded: 0.000047 seconds
#
#  10156: 0.850440, 0.407517 avg loss, 0.001000 rate, 12.544930 seconds, 649984 images
# Loaded: 0.000069 seconds
#
#  10157: 0.130667, 0.379832 avg loss, 0.001000 rate, 12.537440 seconds, 650048 images
# Loaded: 0.000052 seconds
#
#  10158: 0.383272, 0.380176 avg loss, 0.001000 rate, 12.530228 seconds, 650112 images
# Loaded: 0.000067 seconds
#
#  10159: 0.088825, 0.351041 avg loss, 0.001000 rate, 12.523027 seconds, 650176 images
# Loaded: 0.000056 seconds
#
#  10160: 0.659873, 0.381924 avg loss, 0.001000 rate, 12.560549 seconds, 650240 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000054 seconds
#
#  10161: 0.654235, 0.409155 avg loss, 0.001000 rate, 8.065029 seconds, 650304 images
# Loaded: 0.000060 seconds
#
#  10162: 0.364644, 0.404704 avg loss, 0.001000 rate, 8.367171 seconds, 650368 images
# Loaded: 0.000049 seconds
#
#  10163: 0.263351, 0.390569 avg loss, 0.001000 rate, 8.403191 seconds, 650432 images
# Loaded: 0.000050 seconds
#
#  10164: 0.166215, 0.368133 avg loss, 0.001000 rate, 8.379118 seconds, 650496 images
# Loaded: 0.000046 seconds
#
#  10165: 0.502065, 0.381526 avg loss, 0.001000 rate, 8.412405 seconds, 650560 images
# Loaded: 0.000058 seconds
#
#  10166: 0.115472, 0.354921 avg loss, 0.001000 rate, 8.367985 seconds, 650624 images
# Loaded: 0.000055 seconds
#
#  10167: 0.208312, 0.340260 avg loss, 0.001000 rate, 8.396568 seconds, 650688 images
# Loaded: 0.000056 seconds
#
#  10168: 0.241377, 0.330372 avg loss, 0.001000 rate, 8.379463 seconds, 650752 images
# Loaded: 0.000049 seconds
#
#  10169: 0.186539, 0.315989 avg loss, 0.001000 rate, 8.395451 seconds, 650816 images
# Loaded: 0.000051 seconds
#
#  10170: 0.186010, 0.302991 avg loss, 0.001000 rate, 8.385855 seconds, 650880 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 12.46 MB
#  CUDA allocate done!
# Loaded: 0.000085 seconds
#
#  10171: 0.296498, 0.302341 avg loss, 0.001000 rate, 10.862841 seconds, 650944 images
# Loaded: 0.000068 seconds
#
#  10172: 0.696734, 0.341781 avg loss, 0.001000 rate, 11.313112 seconds, 651008 images
# Loaded: 0.000053 seconds
#
#  10173: 0.474199, 0.355022 avg loss, 0.001000 rate, 11.290711 seconds, 651072 images
# Loaded: 0.000069 seconds
#
#  10174: 0.331499, 0.352670 avg loss, 0.001000 rate, 11.328027 seconds, 651136 images
# Loaded: 0.000131 seconds
#
#  10175: 0.204707, 0.337874 avg loss, 0.001000 rate, 11.300347 seconds, 651200 images
# Loaded: 0.000064 seconds
#
#  10176: 0.538994, 0.357986 avg loss, 0.001000 rate, 11.304193 seconds, 651264 images
# Loaded: 0.000066 seconds
#
#  10177: 0.245565, 0.346744 avg loss, 0.001000 rate, 11.307725 seconds, 651328 images
# Loaded: 0.000053 seconds
#
#  10178: 0.247249, 0.336794 avg loss, 0.001000 rate, 11.290288 seconds, 651392 images
# Loaded: 0.000052 seconds
#
#  10179: 0.544492, 0.357564 avg loss, 0.001000 rate, 11.261786 seconds, 651456 images
# Loaded: 0.000047 seconds
#
#  10180: 0.344177, 0.356225 avg loss, 0.001000 rate, 11.287305 seconds, 651520 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000060 seconds
#
#  10181: 0.355474, 0.356150 avg loss, 0.001000 rate, 21.971408 seconds, 651584 images
# Loaded: 0.000073 seconds
#
#  10182: 0.556132, 0.376148 avg loss, 0.001000 rate, 22.770970 seconds, 651648 images
# Loaded: 0.000049 seconds
#
#  10183: 0.138036, 0.352337 avg loss, 0.001000 rate, 22.735229 seconds, 651712 images
# Loaded: 0.000056 seconds
#
#  10184: 0.583268, 0.375430 avg loss, 0.001000 rate, 22.778983 seconds, 651776 images
# Loaded: 0.000051 seconds
#
#  10185: 0.349117, 0.372799 avg loss, 0.001000 rate, 22.732816 seconds, 651840 images
# Loaded: 0.000056 seconds
#
#  10186: 0.654102, 0.400929 avg loss, 0.001000 rate, 22.768354 seconds, 651904 images
# Loaded: 0.000083 seconds
#
#  10187: 0.362502, 0.397086 avg loss, 0.001000 rate, 22.726819 seconds, 651968 images
# Loaded: 0.000051 seconds
#
#  10188: 0.189155, 0.376293 avg loss, 0.001000 rate, 22.733354 seconds, 652032 images
# Loaded: 0.000050 seconds
#
#  10189: 0.159291, 0.354593 avg loss, 0.001000 rate, 22.752093 seconds, 652096 images
# Loaded: 0.000052 seconds
#
#  10190: 0.148305, 0.333964 avg loss, 0.001000 rate, 22.707237 seconds, 652160 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.223998 seconds
#
#  10191: 0.332622, 0.333830 avg loss, 0.001000 rate, 19.740672 seconds, 652224 images
# Loaded: 0.000052 seconds
#
#  10192: 0.168220, 0.317269 avg loss, 0.001000 rate, 20.524543 seconds, 652288 images
# Loaded: 0.000113 seconds
#
#  10193: 0.645188, 0.350061 avg loss, 0.001000 rate, 20.554961 seconds, 652352 images
# Loaded: 0.000051 seconds
#
#  10194: 0.151658, 0.330221 avg loss, 0.001000 rate, 20.488312 seconds, 652416 images
# Loaded: 0.000067 seconds
#
#  10195: 0.299037, 0.327102 avg loss, 0.001000 rate, 20.509460 seconds, 652480 images
# Loaded: 0.000058 seconds
#
#  10196: 0.465273, 0.340919 avg loss, 0.001000 rate, 20.538802 seconds, 652544 images
# Loaded: 0.000051 seconds
#
#  10197: 0.503145, 0.357142 avg loss, 0.001000 rate, 20.494377 seconds, 652608 images
# Loaded: 0.000102 seconds
#
#  10198: 0.200538, 0.341482 avg loss, 0.001000 rate, 20.530473 seconds, 652672 images
# Loaded: 0.000058 seconds
#
#  10199: 0.336358, 0.340969 avg loss, 0.001000 rate, 20.536072 seconds, 652736 images
# Loaded: 0.000050 seconds
#
#  10200: 0.164498, 0.323322 avg loss, 0.001000 rate, 20.501938 seconds, 652800 images
# Saving weights to /content/gdrive/My Drive/darknet/backup//sub-yolov3_16div_last.weights
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000065 seconds
#
#  10201: 0.288369, 0.319827 avg loss, 0.001000 rate, 8.141402 seconds, 652864 images
# Loaded: 0.000048 seconds
#
#  10202: 0.404560, 0.328300 avg loss, 0.001000 rate, 8.390667 seconds, 652928 images
# Loaded: 0.000059 seconds
#
#  10203: 0.500757, 0.345546 avg loss, 0.001000 rate, 8.400399 seconds, 652992 images
# Loaded: 0.000058 seconds
#
#  10204: 0.691863, 0.380178 avg loss, 0.001000 rate, 8.393838 seconds, 653056 images
# Loaded: 0.000059 seconds
#
#  10205: 0.124419, 0.354602 avg loss, 0.001000 rate, 8.386888 seconds, 653120 images
# Loaded: 0.000079 seconds
#
#  10206: 0.450764, 0.364218 avg loss, 0.001000 rate, 8.371213 seconds, 653184 images
# Loaded: 0.000053 seconds
#
#  10207: 0.501666, 0.377963 avg loss, 0.001000 rate, 8.393891 seconds, 653248 images
# Loaded: 0.000053 seconds
#
#  10208: 0.471923, 0.387359 avg loss, 0.001000 rate, 8.446664 seconds, 653312 images
# Loaded: 0.000087 seconds
#
#  10209: 0.114886, 0.360112 avg loss, 0.001000 rate, 8.410778 seconds, 653376 images
# Loaded: 0.000054 seconds
#
#  10210: 0.167970, 0.340897 avg loss, 0.001000 rate, 8.404982 seconds, 653440 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000045 seconds
#
#  10211: 0.351688, 0.341976 avg loss, 0.001000 rate, 15.618977 seconds, 653504 images
# Loaded: 0.000044 seconds
#
#  10212: 0.093244, 0.317103 avg loss, 0.001000 rate, 16.164067 seconds, 653568 images
# Loaded: 0.000052 seconds
#
#  10213: 0.386455, 0.324038 avg loss, 0.001000 rate, 16.162094 seconds, 653632 images
# Loaded: 0.000062 seconds
#
#  10214: 0.150698, 0.306704 avg loss, 0.001000 rate, 16.184356 seconds, 653696 images
# Loaded: 0.000087 seconds
#
#  10215: 0.121969, 0.288231 avg loss, 0.001000 rate, 16.089625 seconds, 653760 images
# Loaded: 0.000058 seconds
#
#  10216: 0.281285, 0.287536 avg loss, 0.001000 rate, 16.206418 seconds, 653824 images
# Loaded: 0.000070 seconds
#
#  10217: 0.136511, 0.272434 avg loss, 0.001000 rate, 16.109402 seconds, 653888 images
# Loaded: 0.000067 seconds
#
#  10218: 1.068427, 0.352033 avg loss, 0.001000 rate, 16.165917 seconds, 653952 images
# Loaded: 0.000053 seconds
#
#  10219: 0.322685, 0.349098 avg loss, 0.001000 rate, 16.086621 seconds, 654016 images
# Loaded: 0.000049 seconds
#
#  10220: 0.265664, 0.340755 avg loss, 0.001000 rate, 16.185247 seconds, 654080 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000062 seconds
#
#  10221: 0.281882, 0.334867 avg loss, 0.001000 rate, 8.096408 seconds, 654144 images
# Loaded: 0.000067 seconds
#
#  10222: 0.176480, 0.319029 avg loss, 0.001000 rate, 8.386679 seconds, 654208 images
# Loaded: 0.000044 seconds
#
#  10223: 0.654049, 0.352531 avg loss, 0.001000 rate, 8.386275 seconds, 654272 images
# Loaded: 0.000049 seconds
#
#  10224: 1.087626, 0.426040 avg loss, 0.001000 rate, 8.384259 seconds, 654336 images
# Loaded: 0.000050 seconds
#
#  10225: 0.394971, 0.422933 avg loss, 0.001000 rate, 8.403496 seconds, 654400 images
# Loaded: 0.000067 seconds
#
#  10226: 0.411767, 0.421817 avg loss, 0.001000 rate, 8.370686 seconds, 654464 images
# Loaded: 0.000069 seconds
#
#  10227: 0.221694, 0.401804 avg loss, 0.001000 rate, 8.392831 seconds, 654528 images
# Loaded: 0.000064 seconds
#
#  10228: 0.210345, 0.382658 avg loss, 0.001000 rate, 8.372547 seconds, 654592 images
# Loaded: 0.000053 seconds
#
#  10229: 0.369821, 0.381375 avg loss, 0.001000 rate, 8.394762 seconds, 654656 images
# Loaded: 0.000067 seconds
#
#  10230: 0.321149, 0.375352 avg loss, 0.001000 rate, 8.365454 seconds, 654720 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000064 seconds
#
#  10231: 0.207309, 0.358548 avg loss, 0.001000 rate, 14.349660 seconds, 654784 images
# Loaded: 0.000075 seconds
#
#  10232: 0.211517, 0.343845 avg loss, 0.001000 rate, 14.843486 seconds, 654848 images
# Loaded: 0.000057 seconds
#
#  10233: 0.599472, 0.369407 avg loss, 0.001000 rate, 14.862570 seconds, 654912 images
# Loaded: 0.000061 seconds
#
#  10234: 0.341482, 0.366615 avg loss, 0.001000 rate, 14.860322 seconds, 654976 images
# Loaded: 0.000060 seconds
#
#  10235: 0.261988, 0.356152 avg loss, 0.001000 rate, 14.851305 seconds, 655040 images
# Loaded: 0.000050 seconds
#
#  10236: 0.076302, 0.328167 avg loss, 0.001000 rate, 14.846955 seconds, 655104 images
# Loaded: 0.000066 seconds
#
#  10237: 0.360413, 0.331392 avg loss, 0.001000 rate, 14.890516 seconds, 655168 images
# Loaded: 0.000081 seconds
#
#  10238: 0.594448, 0.357697 avg loss, 0.001000 rate, 14.868007 seconds, 655232 images
# Loaded: 0.000037 seconds
#
#  10239: 0.302865, 0.352214 avg loss, 0.001000 rate, 14.853683 seconds, 655296 images
# Loaded: 0.000060 seconds
#
#  10240: 0.332407, 0.350233 avg loss, 0.001000 rate, 14.859810 seconds, 655360 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 10.62 MB
#  CUDA allocate done!
# Loaded: 0.000050 seconds
#
#  10241: 0.126191, 0.327829 avg loss, 0.001000 rate, 9.321131 seconds, 655424 images
# Loaded: 0.000055 seconds
#
#  10242: 0.123917, 0.307438 avg loss, 0.001000 rate, 9.690389 seconds, 655488 images
# Loaded: 0.000045 seconds
#
#  10243: 0.195362, 0.296230 avg loss, 0.001000 rate, 9.712919 seconds, 655552 images
# Loaded: 0.000091 seconds
#
#  10244: 0.197455, 0.286353 avg loss, 0.001000 rate, 9.708726 seconds, 655616 images
# Loaded: 0.000051 seconds
#
#  10245: 0.262923, 0.284010 avg loss, 0.001000 rate, 9.717345 seconds, 655680 images
# Loaded: 0.000080 seconds
#
#  10246: 0.227352, 0.278344 avg loss, 0.001000 rate, 9.713730 seconds, 655744 images
# Loaded: 0.000064 seconds
#
#  10247: 0.107018, 0.261211 avg loss, 0.001000 rate, 9.684712 seconds, 655808 images
# Loaded: 0.000054 seconds
#
#  10248: 0.442108, 0.279301 avg loss, 0.001000 rate, 9.731919 seconds, 655872 images
# Loaded: 0.000073 seconds
#
#  10249: 0.110194, 0.262390 avg loss, 0.001000 rate, 9.696361 seconds, 655936 images
# Loaded: 0.000077 seconds
#
#  10250: 0.143871, 0.250538 avg loss, 0.001000 rate, 9.708760 seconds, 656000 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 10.62 MB
#  CUDA allocate done!
# Loaded: 0.000065 seconds
#
#  10251: 0.098706, 0.235355 avg loss, 0.001000 rate, 9.331449 seconds, 656064 images
# Loaded: 0.000048 seconds
#
#  10252: 0.070717, 0.218891 avg loss, 0.001000 rate, 9.664636 seconds, 656128 images
# Loaded: 0.000132 seconds
#
#  10253: 0.309717, 0.227974 avg loss, 0.001000 rate, 9.714904 seconds, 656192 images
# Loaded: 0.000045 seconds
#
#  10254: 0.156345, 0.220811 avg loss, 0.001000 rate, 9.664878 seconds, 656256 images
# Loaded: 0.000049 seconds
#
#  10255: 0.612114, 0.259941 avg loss, 0.001000 rate, 9.686148 seconds, 656320 images
# Loaded: 0.000056 seconds
#
#  10256: 0.092175, 0.243165 avg loss, 0.001000 rate, 9.648887 seconds, 656384 images
# Loaded: 0.000052 seconds
#
#  10257: 0.413249, 0.260173 avg loss, 0.001000 rate, 9.661472 seconds, 656448 images
# Loaded: 0.000053 seconds
#
#  10258: 0.151108, 0.249267 avg loss, 0.001000 rate, 9.644829 seconds, 656512 images
# Loaded: 0.000049 seconds
#
#  10259: 0.471609, 0.271501 avg loss, 0.001000 rate, 9.654789 seconds, 656576 images
# Loaded: 0.000073 seconds
#
#  10260: 0.893614, 0.333712 avg loss, 0.001000 rate, 9.651296 seconds, 656640 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 10.62 MB
#  CUDA allocate done!
# Loaded: 0.378828 seconds
#
#  10261: 0.249192, 0.325260 avg loss, 0.001000 rate, 9.281730 seconds, 656704 images
# Loaded: 0.000052 seconds
#
#  10262: 0.315415, 0.324276 avg loss, 0.001000 rate, 9.655449 seconds, 656768 images
# Loaded: 0.000055 seconds
#
#  10263: 0.270477, 0.318896 avg loss, 0.001000 rate, 9.635930 seconds, 656832 images
# Loaded: 0.000060 seconds
#
#  10264: 0.134143, 0.300420 avg loss, 0.001000 rate, 9.650093 seconds, 656896 images
# Loaded: 0.000050 seconds
#
#  10265: 0.216288, 0.292007 avg loss, 0.001000 rate, 9.637394 seconds, 656960 images
# Loaded: 0.000081 seconds
#
#  10266: 0.418389, 0.304645 avg loss, 0.001000 rate, 9.656794 seconds, 657024 images
# Loaded: 0.000055 seconds
#
#  10267: 0.616209, 0.335802 avg loss, 0.001000 rate, 9.639394 seconds, 657088 images
# Loaded: 0.000066 seconds
#
#  10268: 0.266158, 0.328837 avg loss, 0.001000 rate, 9.629698 seconds, 657152 images
# Loaded: 0.000041 seconds
#
#  10269: 0.308738, 0.326827 avg loss, 0.001000 rate, 9.641780 seconds, 657216 images
# Loaded: 0.000047 seconds
#
#  10270: 0.171013, 0.311246 avg loss, 0.001000 rate, 9.638944 seconds, 657280 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000050 seconds
#
#  10271: 0.247017, 0.304823 avg loss, 0.001000 rate, 11.944565 seconds, 657344 images
# Loaded: 0.000070 seconds
#
#  10272: 0.304778, 0.304819 avg loss, 0.001000 rate, 12.441381 seconds, 657408 images
# Loaded: 0.000058 seconds
#
#  10273: 0.965145, 0.370851 avg loss, 0.001000 rate, 12.490642 seconds, 657472 images
# Loaded: 0.000036 seconds
#
#  10274: 0.235068, 0.357273 avg loss, 0.001000 rate, 12.433789 seconds, 657536 images
# Loaded: 0.000047 seconds
#
#  10275: 0.246157, 0.346161 avg loss, 0.001000 rate, 12.448290 seconds, 657600 images
# Loaded: 0.000054 seconds
#
#  10276: 0.273739, 0.338919 avg loss, 0.001000 rate, 12.449051 seconds, 657664 images
# Loaded: 0.000066 seconds
#
#  10277: 0.139555, 0.318983 avg loss, 0.001000 rate, 12.459591 seconds, 657728 images
# Loaded: 0.000047 seconds
#
#  10278: 0.235917, 0.310676 avg loss, 0.001000 rate, 12.440061 seconds, 657792 images
# Loaded: 0.000061 seconds
#
#  10279: 0.234810, 0.303089 avg loss, 0.001000 rate, 12.442049 seconds, 657856 images
# Loaded: 0.000079 seconds
#
#  10280: 0.287181, 0.301499 avg loss, 0.001000 rate, 12.452976 seconds, 657920 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000097 seconds
#
#  10281: 0.598760, 0.331225 avg loss, 0.001000 rate, 21.829608 seconds, 657984 images
# Loaded: 0.000058 seconds
#
#  10282: 0.663013, 0.364404 avg loss, 0.001000 rate, 22.601180 seconds, 658048 images
# Loaded: 0.000068 seconds
#
#  10283: 0.212077, 0.349171 avg loss, 0.001000 rate, 22.568748 seconds, 658112 images
# Loaded: 0.000065 seconds
#
#  10284: 0.215582, 0.335812 avg loss, 0.001000 rate, 22.554207 seconds, 658176 images
# Loaded: 0.000048 seconds
#
#  10285: 0.148951, 0.317126 avg loss, 0.001000 rate, 22.567485 seconds, 658240 images
# Loaded: 0.000050 seconds
#
#  10286: 0.227277, 0.308141 avg loss, 0.001000 rate, 22.594623 seconds, 658304 images
# Loaded: 0.000055 seconds
#
#  10287: 0.336836, 0.311011 avg loss, 0.001000 rate, 22.602428 seconds, 658368 images
# Loaded: 0.000040 seconds
#
#  10288: 0.990146, 0.378924 avg loss, 0.001000 rate, 22.714664 seconds, 658432 images
# Loaded: 0.000048 seconds
#
#  10289: 0.151161, 0.356148 avg loss, 0.001000 rate, 22.587422 seconds, 658496 images
# Loaded: 0.000069 seconds
#
#  10290: 0.413521, 0.361885 avg loss, 0.001000 rate, 22.571210 seconds, 658560 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000057 seconds
#
#  10291: 0.144196, 0.340116 avg loss, 0.001000 rate, 8.002239 seconds, 658624 images
# Loaded: 0.000056 seconds
#
#  10292: 0.492823, 0.355387 avg loss, 0.001000 rate, 8.325346 seconds, 658688 images
# Loaded: 0.000051 seconds
#
#  10293: 0.292691, 0.349117 avg loss, 0.001000 rate, 8.341365 seconds, 658752 images
# Loaded: 0.000055 seconds
#
#  10294: 0.277963, 0.342002 avg loss, 0.001000 rate, 8.352971 seconds, 658816 images
# Loaded: 0.000062 seconds
#
#  10295: 0.398052, 0.347607 avg loss, 0.001000 rate, 8.332445 seconds, 658880 images
# Loaded: 0.000037 seconds
#
#  10296: 0.549464, 0.367793 avg loss, 0.001000 rate, 8.351363 seconds, 658944 images
# Loaded: 0.000113 seconds
#
#  10297: 0.330844, 0.364098 avg loss, 0.001000 rate, 8.330754 seconds, 659008 images
# Loaded: 0.000053 seconds
#
#  10298: 0.482464, 0.375934 avg loss, 0.001000 rate, 8.327434 seconds, 659072 images
# Loaded: 0.000049 seconds
#
#  10299: 0.287028, 0.367044 avg loss, 0.001000 rate, 8.340132 seconds, 659136 images
# Loaded: 0.000062 seconds
#
#  10300: 0.214294, 0.351769 avg loss, 0.001000 rate, 8.347161 seconds, 659200 images
# Saving weights to /content/gdrive/My Drive/darknet/backup//sub-yolov3_16div_last.weights
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000050 seconds
#
#  10301: 0.240867, 0.340679 avg loss, 0.001000 rate, 15.542861 seconds, 659264 images
# Loaded: 0.000054 seconds
#
#  10302: 0.423012, 0.348912 avg loss, 0.001000 rate, 16.137432 seconds, 659328 images
# Loaded: 0.000058 seconds
#
#  10303: 0.273992, 0.341420 avg loss, 0.001000 rate, 16.185170 seconds, 659392 images
# Loaded: 0.000082 seconds
#
#  10304: 0.203149, 0.327593 avg loss, 0.001000 rate, 16.143614 seconds, 659456 images
# Loaded: 0.000049 seconds
#
#  10305: 0.303258, 0.325159 avg loss, 0.001000 rate, 16.170821 seconds, 659520 images
# Loaded: 0.000071 seconds
#
#  10306: 0.160924, 0.308736 avg loss, 0.001000 rate, 16.138485 seconds, 659584 images
# Loaded: 0.000050 seconds
#
#  10307: 0.310306, 0.308893 avg loss, 0.001000 rate, 16.141068 seconds, 659648 images
# Loaded: 0.000077 seconds
#
#  10308: 0.208807, 0.298884 avg loss, 0.001000 rate, 16.177614 seconds, 659712 images
# Loaded: 0.000053 seconds
#
#  10309: 0.571466, 0.326142 avg loss, 0.001000 rate, 16.197507 seconds, 659776 images
# Loaded: 0.000049 seconds
#
#  10310: 0.147708, 0.308299 avg loss, 0.001000 rate, 16.209804 seconds, 659840 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000063 seconds
#
#  10311: 0.812863, 0.358755 avg loss, 0.001000 rate, 21.969888 seconds, 659904 images
# Loaded: 0.000062 seconds
#
#  10312: 0.477077, 0.370587 avg loss, 0.001000 rate, 22.766186 seconds, 659968 images
# Loaded: 0.000056 seconds
#
#  10313: 0.293987, 0.362927 avg loss, 0.001000 rate, 22.734727 seconds, 660032 images
# Loaded: 0.000066 seconds
#
#  10314: 0.269435, 0.353578 avg loss, 0.001000 rate, 22.725702 seconds, 660096 images
# Loaded: 0.000056 seconds
#
#  10315: 0.104213, 0.328642 avg loss, 0.001000 rate, 22.770828 seconds, 660160 images
# Loaded: 0.000110 seconds
#
#  10316: 0.165422, 0.312320 avg loss, 0.001000 rate, 22.747146 seconds, 660224 images
# Loaded: 0.000068 seconds
#
#  10317: 0.228163, 0.303904 avg loss, 0.001000 rate, 22.736923 seconds, 660288 images
# Loaded: 0.000059 seconds
#
#  10318: 0.774324, 0.350946 avg loss, 0.001000 rate, 22.790133 seconds, 660352 images
# Loaded: 0.000055 seconds
#
#  10319: 0.346570, 0.350508 avg loss, 0.001000 rate, 22.731564 seconds, 660416 images
# Loaded: 0.000049 seconds
#
#  10320: 0.257477, 0.341205 avg loss, 0.001000 rate, 22.753240 seconds, 660480 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000083 seconds
#
#  10321: 0.258140, 0.332899 avg loss, 0.001000 rate, 12.017934 seconds, 660544 images
# Loaded: 0.000065 seconds
#
#  10322: 0.687156, 0.368325 avg loss, 0.001000 rate, 12.538004 seconds, 660608 images
# Loaded: 0.000066 seconds
#
#  10323: 0.594321, 0.390924 avg loss, 0.001000 rate, 12.543621 seconds, 660672 images
# Loaded: 0.000051 seconds
#
#  10324: 0.118670, 0.363699 avg loss, 0.001000 rate, 12.539772 seconds, 660736 images
# Loaded: 0.000053 seconds
#
#  10325: 0.217783, 0.349107 avg loss, 0.001000 rate, 12.540853 seconds, 660800 images
# Loaded: 0.000074 seconds
#
#  10326: 0.147994, 0.328996 avg loss, 0.001000 rate, 12.527481 seconds, 660864 images
# Loaded: 0.000053 seconds
#
#  10327: 0.290820, 0.325178 avg loss, 0.001000 rate, 12.549584 seconds, 660928 images
# Loaded: 0.000057 seconds
#
#  10328: 0.326820, 0.325342 avg loss, 0.001000 rate, 12.538157 seconds, 660992 images
# Loaded: 0.000051 seconds
#
#  10329: 0.400777, 0.332886 avg loss, 0.001000 rate, 12.550780 seconds, 661056 images
# Loaded: 0.000053 seconds
#
#  10330: 0.506643, 0.350262 avg loss, 0.001000 rate, 12.531068 seconds, 661120 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000052 seconds
#
#  10331: 0.431126, 0.358348 avg loss, 0.001000 rate, 15.516980 seconds, 661184 images
# Loaded: 0.000054 seconds
#
#  10332: 0.339252, 0.356438 avg loss, 0.001000 rate, 16.093988 seconds, 661248 images
# Loaded: 0.000056 seconds
#
#  10333: 0.204000, 0.341195 avg loss, 0.001000 rate, 16.149390 seconds, 661312 images
# Loaded: 0.000059 seconds
#
#  10334: 0.368629, 0.343938 avg loss, 0.001000 rate, 16.159031 seconds, 661376 images
# Loaded: 0.000052 seconds
#
#  10335: 0.732619, 0.382806 avg loss, 0.001000 rate, 16.185806 seconds, 661440 images
# Loaded: 0.000055 seconds
#
#  10336: 0.518030, 0.396329 avg loss, 0.001000 rate, 16.176979 seconds, 661504 images
# Loaded: 0.000050 seconds
#
#  10337: 0.114004, 0.368096 avg loss, 0.001000 rate, 16.148981 seconds, 661568 images
# Loaded: 0.000052 seconds
#
#  10338: 0.315907, 0.362877 avg loss, 0.001000 rate, 16.140620 seconds, 661632 images
# Loaded: 0.000062 seconds
#
# ...
# Loaded: 0.000056 seconds
#
#  10976: 0.493871, 0.368150 avg loss, 0.001000 rate, 8.482215 seconds, 702464 images
# Loaded: 0.000047 seconds
#
#  10977: 0.172162, 0.348551 avg loss, 0.001000 rate, 8.468307 seconds, 702528 images
# Loaded: 0.000043 seconds
#
#  10978: 0.104973, 0.324193 avg loss, 0.001000 rate, 8.469355 seconds, 702592 images
# Loaded: 0.000050 seconds
#
#  10979: 0.506674, 0.342441 avg loss, 0.001000 rate, 8.480250 seconds, 702656 images
# Loaded: 0.000047 seconds
#
#  10980: 0.050962, 0.313293 avg loss, 0.001000 rate, 8.461951 seconds, 702720 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000055 seconds
#
#  10981: 0.402425, 0.322206 avg loss, 0.001000 rate, 15.731936 seconds, 702784 images
# Loaded: 0.000071 seconds
#
#  10982: 0.144966, 0.304482 avg loss, 0.001000 rate, 16.340913 seconds, 702848 images
# Loaded: 0.000052 seconds
#
#  10983: 0.166761, 0.290710 avg loss, 0.001000 rate, 16.337035 seconds, 702912 images
# Loaded: 0.000049 seconds
#
#  10984: 0.228131, 0.284452 avg loss, 0.001000 rate, 16.324045 seconds, 702976 images
# Loaded: 0.000050 seconds
#
#  10985: 0.124412, 0.268448 avg loss, 0.001000 rate, 16.316562 seconds, 703040 images
# Loaded: 0.000096 seconds
#
#  10986: 0.139130, 0.255516 avg loss, 0.001000 rate, 16.287343 seconds, 703104 images
# Loaded: 0.000127 seconds
#
#  10987: 0.568312, 0.286796 avg loss, 0.001000 rate, 16.316518 seconds, 703168 images
# Loaded: 0.000053 seconds
#
#  10988: 0.155401, 0.273656 avg loss, 0.001000 rate, 16.293752 seconds, 703232 images
# Loaded: 0.000063 seconds
#
#  10989: 0.381523, 0.284443 avg loss, 0.001000 rate, 16.334207 seconds, 703296 images
# Loaded: 0.000072 seconds
#
#  10990: 0.194058, 0.275405 avg loss, 0.001000 rate, 16.336232 seconds, 703360 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000081 seconds
#
#  10991: 0.204752, 0.268339 avg loss, 0.001000 rate, 8.151858 seconds, 703424 images
# Loaded: 0.000040 seconds
#
#  10992: 0.130304, 0.254536 avg loss, 0.001000 rate, 8.464090 seconds, 703488 images
# Loaded: 0.000063 seconds
#
#  10993: 0.519223, 0.281005 avg loss, 0.001000 rate, 8.476850 seconds, 703552 images
# Loaded: 0.000058 seconds
#
#  10994: 0.224935, 0.275398 avg loss, 0.001000 rate, 8.462828 seconds, 703616 images
# Loaded: 0.000068 seconds
#
#  10995: 0.207519, 0.268610 avg loss, 0.001000 rate, 8.466055 seconds, 703680 images
# Loaded: 0.000039 seconds
#
#  10996: 0.196270, 0.261376 avg loss, 0.001000 rate, 8.459780 seconds, 703744 images
# Loaded: 0.000047 seconds
#
#  10997: 0.148871, 0.250125 avg loss, 0.001000 rate, 8.478210 seconds, 703808 images
# Loaded: 0.000052 seconds
#
#  10998: 0.178167, 0.242930 avg loss, 0.001000 rate, 8.449724 seconds, 703872 images
# Loaded: 0.000048 seconds
#
#  10999: 0.154501, 0.234087 avg loss, 0.001000 rate, 8.465249 seconds, 703936 images
# Loaded: 0.000049 seconds
#
#  11000: 0.143835, 0.225062 avg loss, 0.001000 rate, 8.486801 seconds, 704000 images
# Saving weights to /content/gdrive/My Drive/darknet/backup//sub-yolov3_16div_11000.weights
# Saving weights to /content/gdrive/My Drive/darknet/backup//sub-yolov3_16div_last.weights
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000058 seconds
#
#  11001: 0.284724, 0.231028 avg loss, 0.001000 rate, 18.162384 seconds, 704064 images
# Loaded: 0.000059 seconds
#
#  11002: 0.109420, 0.218867 avg loss, 0.001000 rate, 18.818183 seconds, 704128 images
# Loaded: 0.000050 seconds
#
#  11003: 0.214910, 0.218471 avg loss, 0.001000 rate, 18.842690 seconds, 704192 images
# Loaded: 0.000053 seconds
#
#  11004: 0.520443, 0.248668 avg loss, 0.001000 rate, 18.845392 seconds, 704256 images
# Loaded: 0.000059 seconds
#
#  11005: 0.371105, 0.260912 avg loss, 0.001000 rate, 18.850130 seconds, 704320 images
# Loaded: 0.000051 seconds
#
#  11006: 0.889238, 0.323745 avg loss, 0.001000 rate, 18.829655 seconds, 704384 images
# Loaded: 0.000052 seconds
#
#  11007: 0.161111, 0.307481 avg loss, 0.001000 rate, 18.844119 seconds, 704448 images
# Loaded: 0.000054 seconds
#
#  11008: 0.097754, 0.286509 avg loss, 0.001000 rate, 18.803643 seconds, 704512 images
# Loaded: 0.000048 seconds
#
#  11009: 0.269521, 0.284810 avg loss, 0.001000 rate, 18.835905 seconds, 704576 images
# Loaded: 0.000080 seconds
#
#  11010: 0.427241, 0.299053 avg loss, 0.001000 rate, 18.825396 seconds, 704640 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.157078 seconds
#
#  11011: 0.235593, 0.292707 avg loss, 0.001000 rate, 18.138436 seconds, 704704 images
# Loaded: 0.000085 seconds
#
#  11012: 0.399459, 0.303382 avg loss, 0.001000 rate, 18.856425 seconds, 704768 images
# Loaded: 0.000046 seconds
#
#  11013: 0.277773, 0.300821 avg loss, 0.001000 rate, 18.821114 seconds, 704832 images
# Loaded: 0.000054 seconds
#
#  11014: 0.259291, 0.296668 avg loss, 0.001000 rate, 18.815594 seconds, 704896 images
# Loaded: 0.000051 seconds
#
#  11015: 0.120449, 0.279046 avg loss, 0.001000 rate, 18.867466 seconds, 704960 images
# Loaded: 0.000048 seconds
#
#  11016: 0.194208, 0.270562 avg loss, 0.001000 rate, 18.834070 seconds, 705024 images
# Loaded: 0.000056 seconds
#
#  11017: 0.416048, 0.285111 avg loss, 0.001000 rate, 18.849583 seconds, 705088 images
# Loaded: 0.000051 seconds
#
#  11018: 0.314560, 0.288056 avg loss, 0.001000 rate, 18.855398 seconds, 705152 images
# Loaded: 0.000068 seconds
#
#  11019: 0.207151, 0.279965 avg loss, 0.001000 rate, 18.841816 seconds, 705216 images
# Loaded: 0.000051 seconds
#
#  11020: 0.668664, 0.318835 avg loss, 0.001000 rate, 18.870343 seconds, 705280 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000063 seconds
#
#  11021: 0.238953, 0.310847 avg loss, 0.001000 rate, 12.155687 seconds, 705344 images
# Loaded: 0.000064 seconds
#
#  11022: 0.341066, 0.313869 avg loss, 0.001000 rate, 12.664741 seconds, 705408 images
# Loaded: 0.000049 seconds
#
#  11023: 0.249873, 0.307469 avg loss, 0.001000 rate, 12.689843 seconds, 705472 images
# Loaded: 0.000055 seconds
#
#  11024: 0.255053, 0.302228 avg loss, 0.001000 rate, 12.669700 seconds, 705536 images
# Loaded: 0.000044 seconds
#
#  11025: 0.189002, 0.290905 avg loss, 0.001000 rate, 12.653797 seconds, 705600 images
# Loaded: 0.000055 seconds
#
#  11026: 0.259823, 0.287797 avg loss, 0.001000 rate, 12.659240 seconds, 705664 images
# Loaded: 0.000048 seconds
#
#  11027: 0.126151, 0.271632 avg loss, 0.001000 rate, 12.699552 seconds, 705728 images
# Loaded: 0.000040 seconds
#
#  11028: 0.360091, 0.280478 avg loss, 0.001000 rate, 12.676467 seconds, 705792 images
# Loaded: 0.000059 seconds
#
#  11029: 0.311747, 0.283605 avg loss, 0.001000 rate, 12.691898 seconds, 705856 images
# Loaded: 0.000052 seconds
#
#  11030: 0.701249, 0.325369 avg loss, 0.001000 rate, 12.642176 seconds, 705920 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000064 seconds
#
#  11031: 0.152056, 0.308038 avg loss, 0.001000 rate, 12.174659 seconds, 705984 images
# Loaded: 0.000066 seconds
#
#  11032: 0.422644, 0.319499 avg loss, 0.001000 rate, 12.662854 seconds, 706048 images
# Loaded: 0.000052 seconds
#
#  11033: 0.346830, 0.322232 avg loss, 0.001000 rate, 12.663623 seconds, 706112 images
# Loaded: 0.000082 seconds
#
#  11034: 0.124559, 0.302465 avg loss, 0.001000 rate, 12.655059 seconds, 706176 images
# Loaded: 0.000064 seconds
#
#  11035: 0.423219, 0.314540 avg loss, 0.001000 rate, 12.703252 seconds, 706240 images
# Loaded: 0.000046 seconds
#
#  11036: 0.204791, 0.303565 avg loss, 0.001000 rate, 12.648273 seconds, 706304 images
# Loaded: 0.000063 seconds
#
#  11037: 0.085693, 0.281778 avg loss, 0.001000 rate, 12.662710 seconds, 706368 images
# Loaded: 0.000081 seconds
#
#  11038: 0.373852, 0.290985 avg loss, 0.001000 rate, 12.665443 seconds, 706432 images
# Loaded: 0.000050 seconds
#
#  11039: 0.202276, 0.282114 avg loss, 0.001000 rate, 12.655961 seconds, 706496 images
# Loaded: 0.000048 seconds
#
#  11040: 0.073648, 0.261268 avg loss, 0.001000 rate, 12.649010 seconds, 706560 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 10.62 MB
#  CUDA allocate done!
# Loaded: 0.000054 seconds
#
#  11041: 0.185757, 0.253717 avg loss, 0.001000 rate, 9.447374 seconds, 706624 images
# Loaded: 0.000053 seconds
#
#  11042: 0.202968, 0.248642 avg loss, 0.001000 rate, 9.799358 seconds, 706688 images
# Loaded: 0.000061 seconds
#
#  11043: 0.434019, 0.267180 avg loss, 0.001000 rate, 9.840016 seconds, 706752 images
# Loaded: 0.000056 seconds
#
#  11044: 0.248411, 0.265303 avg loss, 0.001000 rate, 9.829500 seconds, 706816 images
# Loaded: 0.000042 seconds
#
#  11045: 0.166747, 0.255447 avg loss, 0.001000 rate, 9.827650 seconds, 706880 images
# Loaded: 0.000058 seconds
#
#  11046: 0.151525, 0.245055 avg loss, 0.001000 rate, 9.810928 seconds, 706944 images
# Loaded: 0.000049 seconds
#
#  11047: 0.261116, 0.246661 avg loss, 0.001000 rate, 9.820513 seconds, 707008 images
# Loaded: 0.000048 seconds
#
#  11048: 0.210969, 0.243092 avg loss, 0.001000 rate, 9.814814 seconds, 707072 images
# Loaded: 0.000050 seconds
#
#  11049: 0.369090, 0.255692 avg loss, 0.001000 rate, 9.827403 seconds, 707136 images
# Loaded: 0.000115 seconds
#
#  11050: 0.123654, 0.242488 avg loss, 0.001000 rate, 9.802317 seconds, 707200 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000049 seconds
#
#  11051: 0.241272, 0.242366 avg loss, 0.001000 rate, 18.153172 seconds, 707264 images
# Loaded: 0.000062 seconds
#
#  11052: 0.355320, 0.253662 avg loss, 0.001000 rate, 18.812619 seconds, 707328 images
# Loaded: 0.000080 seconds
#
#  11053: 0.225695, 0.250865 avg loss, 0.001000 rate, 18.847631 seconds, 707392 images
# Loaded: 0.000058 seconds
#
#  11054: 0.258322, 0.251611 avg loss, 0.001000 rate, 18.840357 seconds, 707456 images
# Loaded: 0.000073 seconds
#
#  11055: 0.171790, 0.243629 avg loss, 0.001000 rate, 18.881204 seconds, 707520 images
# Loaded: 0.000054 seconds
#
#  11056: 0.123260, 0.231592 avg loss, 0.001000 rate, 18.835502 seconds, 707584 images
# Loaded: 0.000059 seconds
#
#  11057: 0.219670, 0.230400 avg loss, 0.001000 rate, 18.884380 seconds, 707648 images
# Loaded: 0.000060 seconds
#
#  11058: 0.088788, 0.216238 avg loss, 0.001000 rate, 18.815229 seconds, 707712 images
# Loaded: 0.000050 seconds
#
#  11059: 0.412985, 0.235913 avg loss, 0.001000 rate, 18.841166 seconds, 707776 images
# Loaded: 0.000053 seconds
#
#  11060: 0.491732, 0.261495 avg loss, 0.001000 rate, 18.794484 seconds, 707840 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 12.46 MB
#  CUDA allocate done!
# Loaded: 0.212141 seconds
#
#  11061: 0.196909, 0.255036 avg loss, 0.001000 rate, 10.932902 seconds, 707904 images
# Loaded: 0.000050 seconds
#
#  11062: 0.589139, 0.288447 avg loss, 0.001000 rate, 11.405866 seconds, 707968 images
# Loaded: 0.000065 seconds
#
#  11063: 0.163764, 0.275978 avg loss, 0.001000 rate, 11.429982 seconds, 708032 images
# Loaded: 0.000049 seconds
#
#  11064: 0.163663, 0.264747 avg loss, 0.001000 rate, 11.400412 seconds, 708096 images
# Loaded: 0.000059 seconds
#
#  11065: 0.309513, 0.269223 avg loss, 0.001000 rate, 11.438513 seconds, 708160 images
# Loaded: 0.000049 seconds
#
#  11066: 0.109935, 0.253295 avg loss, 0.001000 rate, 11.429457 seconds, 708224 images
# Loaded: 0.000069 seconds
#
#  11067: 0.200541, 0.248019 avg loss, 0.001000 rate, 11.406045 seconds, 708288 images
# Loaded: 0.000071 seconds
#
#  11068: 0.474785, 0.270696 avg loss, 0.001000 rate, 11.421982 seconds, 708352 images
# Loaded: 0.000063 seconds
#
#  11069: 0.287815, 0.272408 avg loss, 0.001000 rate, 11.431719 seconds, 708416 images
# Loaded: 0.000044 seconds
#
#  11070: 0.282591, 0.273426 avg loss, 0.001000 rate, 11.424935 seconds, 708480 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000041 seconds
#
#  11071: 0.241461, 0.270230 avg loss, 0.001000 rate, 8.173735 seconds, 708544 images
# Loaded: 0.000043 seconds
#
#  11072: 0.511934, 0.294400 avg loss, 0.001000 rate, 8.473924 seconds, 708608 images
# Loaded: 0.000049 seconds
#
#  11073: 0.374426, 0.302403 avg loss, 0.001000 rate, 8.480337 seconds, 708672 images
# Loaded: 0.000050 seconds
#
#  11074: 0.091229, 0.281285 avg loss, 0.001000 rate, 8.464717 seconds, 708736 images
# Loaded: 0.000070 seconds
#
#  11075: 0.128373, 0.265994 avg loss, 0.001000 rate, 8.485400 seconds, 708800 images
# Loaded: 0.000069 seconds
#
#  11076: 0.116949, 0.251089 avg loss, 0.001000 rate, 8.475102 seconds, 708864 images
# Loaded: 0.000049 seconds
#
#  11077: 0.218716, 0.247852 avg loss, 0.001000 rate, 8.468440 seconds, 708928 images
# Loaded: 0.000061 seconds
#
#  11078: 0.217404, 0.244807 avg loss, 0.001000 rate, 8.475965 seconds, 708992 images
# Loaded: 0.000046 seconds
#
#  11079: 0.375764, 0.257903 avg loss, 0.001000 rate, 8.478825 seconds, 709056 images
# Loaded: 0.000045 seconds
#
#  11080: 0.313536, 0.263466 avg loss, 0.001000 rate, 8.496896 seconds, 709120 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000040 seconds
#
#  11081: 0.359637, 0.273083 avg loss, 0.001000 rate, 20.054416 seconds, 709184 images
# Loaded: 0.000069 seconds
#
#  11082: 0.289829, 0.274758 avg loss, 0.001000 rate, 20.773928 seconds, 709248 images
# Loaded: 0.000050 seconds
#
#  11083: 0.228549, 0.270137 avg loss, 0.001000 rate, 20.673357 seconds, 709312 images
# Loaded: 0.000054 seconds
#
#  11084: 0.301138, 0.273237 avg loss, 0.001000 rate, 20.586325 seconds, 709376 images
# Loaded: 0.000067 seconds
#
#  11085: 0.062882, 0.252201 avg loss, 0.001000 rate, 20.544361 seconds, 709440 images
# Loaded: 0.000066 seconds
#
#  11086: 0.484388, 0.275420 avg loss, 0.001000 rate, 20.618018 seconds, 709504 images
# Loaded: 0.000064 seconds
#
#  11087: 0.394010, 0.287279 avg loss, 0.001000 rate, 20.547890 seconds, 709568 images
# Loaded: 0.000130 seconds
#
#  11088: 0.295149, 0.288066 avg loss, 0.001000 rate, 20.537860 seconds, 709632 images
# Loaded: 0.000053 seconds
#
#  11089: 0.297630, 0.289023 avg loss, 0.001000 rate, 20.573760 seconds, 709696 images
# Loaded: 0.000057 seconds
#
#  11090: 0.108541, 0.270974 avg loss, 0.001000 rate, 20.546541 seconds, 709760 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000058 seconds
#
#  11091: 0.136833, 0.257560 avg loss, 0.001000 rate, 8.048240 seconds, 709824 images
# Loaded: 0.000056 seconds
#
#  11092: 0.139576, 0.245762 avg loss, 0.001000 rate, 8.386542 seconds, 709888 images
# Loaded: 0.000046 seconds
#
#  11093: 0.338250, 0.255011 avg loss, 0.001000 rate, 8.397417 seconds, 709952 images
# Loaded: 0.000113 seconds
#
#  11094: 0.140943, 0.243604 avg loss, 0.001000 rate, 8.396478 seconds, 710016 images
# Loaded: 0.000072 seconds
#
#  11095: 0.058208, 0.225064 avg loss, 0.001000 rate, 8.385898 seconds, 710080 images
# Loaded: 0.000056 seconds
#
#  11096: 0.201062, 0.222664 avg loss, 0.001000 rate, 8.387583 seconds, 710144 images
# Loaded: 0.000071 seconds
#
#  11097: 0.447713, 0.245169 avg loss, 0.001000 rate, 8.389192 seconds, 710208 images
# Loaded: 0.000057 seconds
#
#  11098: 0.363369, 0.256989 avg loss, 0.001000 rate, 8.399399 seconds, 710272 images
# Loaded: 0.000096 seconds
#
#  11099: 0.153453, 0.246635 avg loss, 0.001000 rate, 8.399164 seconds, 710336 images
# Loaded: 0.000049 seconds
#
#  11100: 0.211830, 0.243155 avg loss, 0.001000 rate, 8.377194 seconds, 710400 images
# Saving weights to /content/gdrive/My Drive/darknet/backup//sub-yolov3_16div_last.weights
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000088 seconds
#
#  11101: 0.284926, 0.247332 avg loss, 0.001000 rate, 21.974134 seconds, 710464 images
# Loaded: 0.000054 seconds
#
#  11102: 0.307783, 0.253377 avg loss, 0.001000 rate, 22.792464 seconds, 710528 images
# Loaded: 0.000086 seconds
#
#  11103: 0.223960, 0.250435 avg loss, 0.001000 rate, 22.743153 seconds, 710592 images
# Loaded: 0.000051 seconds
#
#  11104: 0.440170, 0.269409 avg loss, 0.001000 rate, 22.787313 seconds, 710656 images
# Loaded: 0.000073 seconds
#
#  11105: 0.133252, 0.255793 avg loss, 0.001000 rate, 22.780681 seconds, 710720 images
# Loaded: 0.000057 seconds
# ^C

# %%
# !ls
# Out:
# 3rdparty      cmake		      image_yolov2.sh	     obj
# appveyor.yml  CMakeLists.txt	      image_yolov3.sh	     README.md
# backup	      CMakeSettings.json      img		     results
# build	      darknet		      include		     scripts
# build.ps1     DarknetConfig.cmake.in  json_mjpeg_streams.sh  src
# build.sh      darknet.py	      LICENSE		     video_v2.sh
# cfg	      darknet_video.py	      Makefile		     video_yolov3.sh
# chart.png     data		      net_cam_v3.sh
